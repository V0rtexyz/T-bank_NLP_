# %%
import sys

sys.path.insert(0, "../rusBeIR")

# %%
from beir.datasets.data_loader_hf import HFDataLoader

corpus, queries, qrels = HFDataLoader(
    hf_repo="kaengreg/ria-news", hf_repo_qrels="kaengreg/ria-news", streaming=False, keep_in_memory=False
).load(split="test")

print(f"Corpus: {len(corpus)} documents")
print(f"Queries: {len(queries)} queries")
print(f"Qrels: {len(qrels)} relevance judgments")
# Out:
# A huggingface repository is provided. This will override the data_folder, prefix and *_file arguments.
# corpus.jsonl:   0%|          | 0.00/2.84G [00:00<?, ?B/s]
# ...
# Casting the dataset:   0%|          | 0/704344 [00:00<?, ? examples/s]
# queries.jsonl: 0.00B [00:00, ?B/s]
# ...
# Casting the dataset:   0%|          | 0/10000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       1 from beir.datasets.data_loader_hf import HFDataLoader
#       3 corpus, queries, qrels = HFDataLoader(
#       4     hf_repo="kaengreg/ria-news", hf_repo_qrels="kaengreg/ria-news", streaming=False, keep_in_memory=False
# ----> 5 ).load(split="test")
#       7 print(f"Corpus: {len(corpus)} documents")
#       8 print(f"Queries: {len(queries)} queries")
#
# ...
